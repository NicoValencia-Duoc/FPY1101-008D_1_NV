# %% [markdown]
# <a href="https://colab.research.google.com/github/NicoValencia-Duoc/FPY1101-008D_1_NV/blob/main/Ejercicio%20prueba%20colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1 = int(input("Ingrese primer numero: "))
num2 = int(input("Ingrese segundo numero: "))

suma = num1 + num2

print("El resultado de la suma es: ", suma)
# Out:
# Ingrese primer numero: 5
# Ingrese segundo numero: 20
# El resultado de la suma es:  25
